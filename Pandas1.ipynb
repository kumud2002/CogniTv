# %% [markdown]
# ## Pandas -used for data manipulation and analysis

# %%
import numpy as np 
import pandas as pd
# Creating a MultiIndex DataFrame
df = pd.DataFrame(np.random.randn(6, 4), index=[['A', 'A', 'B', 'B', 'C', 'C'], [1, 2, 1, 2, 1, 2]], columns=['X', 'Y', 'Z', 'W'])

# %%
df
# Out:
#             X         Y         Z         W
# A 1  0.118041  1.654963 -0.559860  0.862181
#   2 -0.876498 -0.761774 -0.352031 -2.502224
# B 1 -1.602282  0.068541 -0.221547 -0.036979
#   2 -0.100374  1.005556 -0.264791 -0.980054
# C 1 -2.019244  2.330996 -1.857757 -0.394670
#   2  0.214406  0.350458 -1.275875  1.222746

# %%
# Using vectorized operations
df['new_column'] = df['X'] + df['Y']
df['new_column']
# Out:
# A  1    1.773004
#    2   -1.638272
# B  1   -1.533740
#    2    0.905182
# C  1    0.311753
#    2    0.564863
# Name: new_column, dtype: float64

# %%
# Boolean indexing
df[df['X'] > 0] #creates a dataframe where values are > than X
df
# Out:
#             X         Y         Z         W  new_column
# A 1  0.118041  1.654963 -0.559860  0.862181    1.773004
#   2 -0.876498 -0.761774 -0.352031 -2.502224   -1.638272
# B 1 -1.602282  0.068541 -0.221547 -0.036979   -1.533740
#   2 -0.100374  1.005556 -0.264791 -0.980054    0.905182
# C 1 -2.019244  2.330996 -1.857757 -0.394670    0.311753
#   2  0.214406  0.350458 -1.275875  1.222746    0.564863

# %%
# Using .loc for label-based indexing
df.loc['A'] #assumes that 'A' is in the index of the DataFrame.
df
# Out:
#             X         Y         Z         W  new_column
# A 1  0.118041  1.654963 -0.559860  0.862181    1.773004
#   2 -0.876498 -0.761774 -0.352031 -2.502224   -1.638272
# B 1 -1.602282  0.068541 -0.221547 -0.036979   -1.533740
#   2 -0.100374  1.005556 -0.264791 -0.980054    0.905182
# C 1 -2.019244  2.330996 -1.857757 -0.394670    0.311753
#   2  0.214406  0.350458 -1.275875  1.222746    0.564863

# %%
# Using .iloc for positional indexing
df.iloc[0:2, 1:3]
df
# Out:
#             X         Y         Z         W  new_column
# A 1  0.118041  1.654963 -0.559860  0.862181    1.773004
#   2 -0.876498 -0.761774 -0.352031 -2.502224   -1.638272
# B 1 -1.602282  0.068541 -0.221547 -0.036979   -1.533740
#   2 -0.100374  1.005556 -0.264791 -0.980054    0.905182
# C 1 -2.019244  2.330996 -1.857757 -0.394670    0.311753
#   2  0.214406  0.350458 -1.275875  1.222746    0.564863

# %%
# Boolean indexing
df[df['X'] > 0]

# Using .loc for label-based indexing
df.loc['A']

# Using .iloc for positional indexing
df.iloc[0:2, 1:3]
# Out:
#             Y         Z
# A 1  1.654963 -0.559860
#   2 -0.761774 -0.352031

# %%
# Grouping by a column and calculating mean
df.groupby('X').mean()

# Grouping by multiple columns
#df.groupby(['X', 'Y']).sum()
# Out:
#                   Y         Z         W  new_column
# X
# -2.019244  2.330996 -1.857757 -0.394670    0.311753
# -1.602282  0.068541 -0.221547 -0.036979   -1.533740
# -0.876498 -0.761774 -0.352031 -2.502224   -1.638272
# -0.100374  1.005556 -0.264791 -0.980054    0.905182
#  0.118041  1.654963 -0.559860  0.862181    1.773004
#  0.214406  0.350458 -1.275875  1.222746    0.564863

# %%
# Grouping by a column and calculating mean
#df.groupby('X').mean()

# Grouping by multiple columns
df.groupby(['X', 'Y']).sum()
# Out:
#                             Z         W  new_column
# X         Y
# -2.019244  2.330996 -1.857757 -0.394670    0.311753
# -1.602282  0.068541 -0.221547 -0.036979   -1.533740
# -0.876498 -0.761774 -0.352031 -2.502224   -1.638272
# -0.100374  1.005556 -0.264791 -0.980054    0.905182
#  0.118041  1.654963 -0.559860  0.862181    1.773004
#  0.214406  0.350458 -1.275875  1.222746    0.564863

# %%
# Grouping by a column and calculating mean
df.groupby('X').mean()

# Grouping by multiple columns
df.groupby(['X', 'Y']).sum()
# Out:
#                             Z         W  new_column
# X         Y
# -2.019244  2.330996 -1.857757 -0.394670    0.311753
# -1.602282  0.068541 -0.221547 -0.036979   -1.533740
# -0.876498 -0.761774 -0.352031 -2.502224   -1.638272
# -0.100374  1.005556 -0.264791 -0.980054    0.905182
#  0.118041  1.654963 -0.559860  0.862181    1.773004
#  0.214406  0.350458 -1.275875  1.222746    0.564863

# %% [markdown]
# ## Handling missing data

# %%
# Dropping NaN values
df.dropna()

# Filling NaN values with a specific value
df.fillna(0)
# Out:
#             X         Y         Z         W  new_column
# A 1  0.118041  1.654963 -0.559860  0.862181    1.773004
#   2 -0.876498 -0.761774 -0.352031 -2.502224   -1.638272
# B 1 -1.602282  0.068541 -0.221547 -0.036979   -1.533740
#   2 -0.100374  1.005556 -0.264791 -0.980054    0.905182
# C 1 -2.019244  2.330996 -1.857757 -0.394670    0.311753
#   2  0.214406  0.350458 -1.275875  1.222746    0.564863

# %%
# Melting a DataFrame
pd.melt(df, id_vars=['X'], value_vars=['Y', 'Z'])
# Out:
#            X variable     value
# 0   0.118041        Y  1.654963
# 1  -0.876498        Y -0.761774
# 2  -1.602282        Y  0.068541
# 3  -0.100374        Y  1.005556
# 4  -2.019244        Y  2.330996
# 5   0.214406        Y  0.350458
# 6   0.118041        Z -0.559860
# 7  -0.876498        Z -0.352031
# 8  -1.602282        Z -0.221547
# 9  -0.100374        Z -0.264791
# 10 -2.019244        Z -1.857757
# 11  0.214406        Z -1.275875

# %%
# Pivoting a DataFrame
df.pivot(index='A', columns='B', values='C')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Himani Munjal\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\Himani Munjal\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Himani Munjal\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'A'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Pivoting a DataFrame
# ----> 2 df.pivot(index='A', columns='B', values='C')
#
# File c:\Users\Himani Munjal\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:8424, in DataFrame.pivot(self, columns, index, values)
#    8419 @Substitution("")
#    8420 @Appender(_shared_docs["pivot"])
#    8421 def pivot(self, *, columns, index=lib.NoDefault, values=lib.NoDefault) -> DataFrame:
#    8422     from pandas.core.reshape.pivot import pivot
# -> 8424     return pivot(self, index=index, columns=columns, values=values)
#
# File c:\Users\Himani Munjal\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\pivot.py:540, in pivot(data, columns, index, values)
#     538         index_list = [Series(data.index, name=data.index.name)]
#     539 else:
# --> 540     index_list = [data[idx] for idx in com.convert_to_list_like(index)]
#     542 data_columns = [data[col] for col in columns_listlike]
#     543 index_list.extend(data_columns)
#
# File c:\Users\Himani Munjal\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\pivot.py:540, in <listcomp>(.0)
#     538         index_list = [Series(data.index, name=data.index.name)]
#     539 else:
# --> 540     index_list = [data[idx] for idx in com.convert_to_list_like(index)]
#     542 data_columns = [data[col] for col in columns_listlike]
#     543 index_list.extend(data_columns)
#
# File c:\Users\Himani Munjal\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\Himani Munjal\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'A'

# %% [markdown]
# ## using lambda

# %%
# Applying a function to each column
df.apply(lambda x: x.max() - x.min()) #apply is used to apply a function along the axis of a DataFrame.
# Out:
# X             2.233649
# Y             3.092771
# Z             1.636210
# W             3.724970
# new_column    3.411275
# dtype: float64

# %%
# Applying a function element-wise
df.applymap(lambda x: x**2) 
#applymap is used to apply a function element-wise to every element in a DataFrame.
# Out:
#             X         Y         Z         W  new_column
# A 1  0.013934  2.738902  0.313443  0.743357    3.143542
#   2  0.768248  0.580300  0.123926  6.261124    2.683935
# B 1  2.567306  0.004698  0.049083  0.001367    2.352359
#   2  0.010075  1.011143  0.070114  0.960506    0.819355
# C 1  4.077346  5.433544  3.451260  0.155765    0.097190
#   2  0.045970  0.122821  1.627857  1.495108    0.319071

# %%
data=[[1,'neha'],[2,'himani'],[3,'harsh']]
df1=pd.DataFrame(data,columns=['rollno','name'])
df1
                 #np.random.
# Out:
#    rollno    name
# 0       1    neha
# 1       2  himani
# 2       3   harsh

# %%
data=[[4,'chirag'],[5,'chetna'],[3,'harsh']]
df2=pd.DataFrame(data,columns=['rollno','na'])
df2
# Out:
#    rollno      na
# 0       4  chirag
# 1       5  chetna
# 2       3    arsh

# %%
# Concatenating DataFrames
pd.concat([df1, df2])
# Out:
#    rollno    name      na
# 0       1    neha     NaN
# 1       2  himani     NaN
# 2       3   harsh     NaN
# 0       4     NaN  chirag
# 1       5     NaN  chetna
# 2       3     NaN    arsh

# %%
# Creating a DateTimeIndex
df.index = pd.date_range('2024-01-01', periods=len(df))
df
# Out:
#                    X         Y         Z         W  new_column
# 2024-01-01  0.118041  1.654963 -0.559860  0.862181    1.773004
# 2024-01-02 -0.876498 -0.761774 -0.352031 -2.502224   -1.638272
# 2024-01-03 -1.602282  0.068541 -0.221547 -0.036979   -1.533740
# 2024-01-04 -0.100374  1.005556 -0.264791 -0.980054    0.905182
# 2024-01-05 -2.019244  2.330996 -1.857757 -0.394670    0.311753
# 2024-01-06  0.214406  0.350458 -1.275875  1.222746    0.564863

# %%
# Resampling time series data
df.resample('M').sum()
# Out:
#                   X        Y         Z      W  new_column
# 2024-01-31 -4.26595  4.64874 -4.531861 -1.829     0.38279

# %%
# Using vectorized operations
df['new_column'] = df['X'] + df['Y']
df
# Out:
#                    X         Y         Z         W  new_column
# 2024-01-01  0.118041  1.654963 -0.559860  0.862181    1.773004
# 2024-01-02 -0.876498 -0.761774 -0.352031 -2.502224   -1.638272
# 2024-01-03 -1.602282  0.068541 -0.221547 -0.036979   -1.533740
# 2024-01-04 -0.100374  1.005556 -0.264791 -0.980054    0.905182
# 2024-01-05 -2.019244  2.330996 -1.857757 -0.394670    0.311753
# 2024-01-06  0.214406  0.350458 -1.275875  1.222746    0.564863
